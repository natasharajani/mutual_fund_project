# %%
import pandas as pd
import os
print(os.getcwd())
file_path=os.path.join('.','data','raw')
full_path=os.path.join(file_path,'02_nav_history.csv')
file_read=pd.read_csv(full_path)
file_read['date']=pd.to_datetime(file_read['date'])
cleaned_data=[]
for a,b in file_read.groupby('amfi_code'):
    start_date=b['date'].min()
    end_date=b['date'].max()
    new_range=pd.date_range(start=start_date,end=end_date,freq='D')
    b=b.set_index('date').reindex(new_range)
    b['amfi_code']=b['amfi_code'].ffill()
    b['nav']=b['nav'].ffill()
    cleaned_data.append(b)
new_nav_clean=pd.concat(cleaned_data)
# Out:
# C:\Users\Natasha\Desktop\mutual_fund_project\mutual_fund_project\notebooks
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       2 import os
#       3 print(os.getcwd())
#       4 file_path=os.path.join('.','data','raw')
#       5 full_path=os.path.join(file_path,'02_nav_history.csv')
# ----> 6 file_read=pd.read_csv(full_path)
#       7 file_read['date']=pd.to_datetime(file_read['date'])
#       8 cleaned_data=[]
#       9 for a,b in file_read.groupby('amfi_code'):
#
# ...
